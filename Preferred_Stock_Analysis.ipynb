# %% [markdown]
# # Valuing preferred stocks using PV of perpetuity

# %% [markdown]
# Will add some complexity to the valuation later:
# - probability of paying out the dividend (based on historical data, earnings estimates, and price volatility)

# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Read information into a table
url = 'http://www.dividend.com/dividend-stocks/preferred-dividend-stocks.php#stocks&sort_name=Symbol&sort_order=ASC&page=1'
tables = pd.read_html(url)
tables
# Out:
# [   \nStock Symbol\n                                   \nCompany Name\n  \
#  0             ABR-A                          Arbor Realty Trust Pref A
#  1             ABR-B  Arbor Realty Trust Cumulative Redeemable Prefe...
#  2             AGM-B       Federal Agricultural Mortgage Corp. PRFD 'B'
#  3             AGNCB  American Capital Agency Corp. - Depositary Sha...
#  4             AHL-C  Aspen Insurance Holdings Limited 5.95% Fixed-t...
#  5             AHT-D  Ashford Hospitality Trust Inc 8.45% Cum Pfd Ser D
#  6             AHT-F  Ashford Hospitality Trust Inc 7.375% Series F ...
#  7             AHT-G  Ashford Hospitality Trust Inc 7.375% Series G ...
#  8             AHT-H  Ashford Hospitality Trust Inc 7.50% Series H C...
#  9             AHT-I  Ashford Hospitality Trust Inc 7.50% Series I C...
#  10            ALL-B                                    Allstate Pref B
#  11            ALL-C  Allstate Corporation (The) Dep Shs Repstg 1/10...
#  12            ALL-D  The Allstate Corporation Leopards Each Represe...
#  13            AMH-D                                Amelot Holdings Inc
#  14            ANH-A  Anworth Mortgage Asset Corp. 8.625% Ser A Cum Pfd
#  15            ARI-C  Apollo Commercial Real Estate Finance 8.00% Se...
#  16            ARR-A     Armour Residential REIT INC Preferred Series A
#  17            ARR-B   ARMOUR Residential REIT, Inc. Preferred Series B
#  18            ASB-C                      Associated Banc-Corp PRFD 'C'
#  19            AXS-D  Axis Capital Holdings Limited Preferred Series...
#
#     \nDividend Yield\n \nCurrent Price\n \nAnnual Dividend\n  \n52-Week High\n  \
#  0               8.04%            $25.65               $2.06             25.98
#  1               7.61%            $25.47               $1.94             25.95
#  2               6.66%            $25.82               $1.72             28.80
#  3               7.47%            $25.95               $1.94             26.87
#  4               5.78%            $25.72               $1.49             28.99
#  5               8.06%            $26.20               $2.11             26.00
#  6               7.72%            $23.87               $1.84              0.00
#  7               7.75%            $23.80               $1.84              0.00
#  8               7.80%            $24.05               $1.88              0.00
#  9               7.83%            $23.94               $1.88              0.00
#  10              4.94%            $25.80               $1.28             28.29
#  11              6.60%            $25.57               $1.69             27.74
#  12              6.44%            $25.71               $1.66             27.98
#  13              6.17%            $26.34               $1.63             27.73
#  14              8.11%            $26.58               $2.16             28.19
#  15              7.82%            $25.58               $2.00              0.00
#  16              8.10%            $25.46               $2.06             25.83
#  17              7.86%            $25.06               $1.97             25.37
#  18              5.88%            $26.03               $1.53             27.50
#  19              5.56%            $24.72               $1.38             25.98
#
#      \n52-Week Low\n
#  0             24.81
#  1             24.59
#  2             25.52
#  3             25.28
#  4             25.21
#  5             25.06
#  6              0.00
#  7              0.00
#  8              0.00
#  9              0.00
#  10            25.10
#  11            25.48
#  12            25.60
#  13            24.61
#  14            25.35
#  15             0.00
#  16            23.71
#  17            24.09
#  18            25.28
#  19            23.79  ]

# %%
# Format the table
type(tables)
type(tables[0])
tables[0].head()
# Out:
#   \nStock Symbol\n                                   \nCompany Name\n  \
# 0            ABR-A                          Arbor Realty Trust Pref A
# 1            ABR-B  Arbor Realty Trust Cumulative Redeemable Prefe...
# 2            AGM-B       Federal Agricultural Mortgage Corp. PRFD 'B'
# 3            AGNCB  American Capital Agency Corp. - Depositary Sha...
# 4            AHL-C  Aspen Insurance Holdings Limited 5.95% Fixed-t...
#
#   \nDividend Yield\n \nCurrent Price\n \nAnnual Dividend\n  \n52-Week High\n  \
# 0              8.04%            $25.65               $2.06             25.98
# 1              7.61%            $25.47               $1.94             25.95
# 2              6.66%            $25.82               $1.72             28.80
# 3              7.47%            $25.95               $1.94             26.87
# 4              5.78%            $25.72               $1.49             28.99
#
#    \n52-Week Low\n
# 0            24.81
# 1            24.59
# 2            25.52
# 3            25.28
# 4            25.21

# %%
# List the data
list(tables[0])

['\nStock Symbol\n',
'\nCompany Name\n',
'\nDividend Yield\n',
'\nCurrent Price\n',
'\nAnnual Dividend\n',
'\n52-Week High\n',
'\n52-Week Low\n']
# Out:
# ['\nStock Symbol\n',
#  '\nCompany Name\n',
#  '\nDividend Yield\n',
#  '\nCurrent Price\n',
#  '\nAnnual Dividend\n',
#  '\n52-Week High\n',
#  '\n52-Week Low\n']

# %%
# Format the data from str to float
a = tables[0][list(tables[0])[2]]
a = a.replace('[\%,]', '', regex=True).astype(float)
b = tables[0][list(tables[0])[4]]
b = b.replace('[\$,]', '', regex=True).astype(float)

# %%
# Add the Perp Value calculated column
tables[0]["Perp Value"] = (1/(a/100))*b

# %%
# Format the data from str to float
c = tables[0]["Perp Value"]
c = c.astype(float)
#d = tables[0]["\nCurrent Price\n"]
#d = d.astype(float)
d = tables[0][list(tables[0])[3]]
d = d.replace('[\$,]', '', regex=True).astype(float)

# %%
# Concat the list of dataframes (tables) into a dataframe
data = pd.concat(tables)
data.head()
# Out:
#   \nStock Symbol\n                                   \nCompany Name\n  \
# 0            ABR-A                          Arbor Realty Trust Pref A
# 1            ABR-B  Arbor Realty Trust Cumulative Redeemable Prefe...
# 2            AGM-B       Federal Agricultural Mortgage Corp. PRFD 'B'
# 3            AGNCB  American Capital Agency Corp. - Depositary Sha...
# 4            AHL-C  Aspen Insurance Holdings Limited 5.95% Fixed-t...
#
#   \nDividend Yield\n \nCurrent Price\n \nAnnual Dividend\n  \n52-Week High\n  \
# 0              8.04%            $25.65               $2.06             25.98
# 1              7.61%            $25.47               $1.94             25.95
# 2              6.66%            $25.82               $1.72             28.80
# 3              7.47%            $25.95               $1.94             26.87
# 4              5.78%            $25.72               $1.49             28.99
#
#    \n52-Week Low\n  Perp Value
# 0            24.81   25.621891
# 1            24.59   25.492773
# 2            25.52   25.825826
# 3            25.28   25.970549
# 4            25.21   25.778547

# %%
# Just checking the headers
#list(data)

# %%
# Rename the headers (makes them easier to work with) 
data.columns = ['Ticker', 'Company_Name','Div_Yld', 'Current_Price', 'Annual_Div', '52_Wk_High', '52_Wk_Low', 'Perp_Value']
data.head()
# Out:
#   Ticker                                       Company_Name Div_Yld  \
# 0  ABR-A                          Arbor Realty Trust Pref A   8.04%
# 1  ABR-B  Arbor Realty Trust Cumulative Redeemable Prefe...   7.61%
# 2  AGM-B       Federal Agricultural Mortgage Corp. PRFD 'B'   6.66%
# 3  AGNCB  American Capital Agency Corp. - Depositary Sha...   7.47%
# 4  AHL-C  Aspen Insurance Holdings Limited 5.95% Fixed-t...   5.78%
#
#   Current_Price Annual_Div  52_Wk_High  52_Wk_Low  Perp_Value
# 0        $25.65      $2.06       25.98      24.81   25.621891
# 1        $25.47      $1.94       25.95      24.59   25.492773
# 2        $25.82      $1.72       28.80      25.52   25.825826
# 3        $25.95      $1.94       26.87      25.28   25.970549
# 4        $25.72      $1.49       28.99      25.21   25.778547

# %%
# Round the data in the Perp_Value column to two decimal points
data.Perp_Value = data.Perp_Value.round(decimals=2)
data.head()
# Out:
#   Ticker                                       Company_Name Div_Yld  \
# 0  ABR-A                          Arbor Realty Trust Pref A   8.04%
# 1  ABR-B  Arbor Realty Trust Cumulative Redeemable Prefe...   7.61%
# 2  AGM-B       Federal Agricultural Mortgage Corp. PRFD 'B'   6.66%
# 3  AGNCB  American Capital Agency Corp. - Depositary Sha...   7.47%
# 4  AHL-C  Aspen Insurance Holdings Limited 5.95% Fixed-t...   5.78%
#
#   Current_Price Annual_Div  52_Wk_High  52_Wk_Low  Perp_Value
# 0        $25.65      $2.06       25.98      24.81       25.62
# 1        $25.47      $1.94       25.95      24.59       25.49
# 2        $25.82      $1.72       28.80      25.52       25.83
# 3        $25.95      $1.94       26.87      25.28       25.97
# 4        $25.72      $1.49       28.99      25.21       25.78

# %%
# Add the Buy Indicator column. 1 = buy; 0 = don't buy
data['Buy_Ind'] = np.where((c > d), '1', '0')
data.head()
# Out:
#   Ticker                                       Company_Name Div_Yld  \
# 0  ABR-A                          Arbor Realty Trust Pref A   8.04%
# 1  ABR-B  Arbor Realty Trust Cumulative Redeemable Prefe...   7.61%
# 2  AGM-B       Federal Agricultural Mortgage Corp. PRFD 'B'   6.66%
# 3  AGNCB  American Capital Agency Corp. - Depositary Sha...   7.47%
# 4  AHL-C  Aspen Insurance Holdings Limited 5.95% Fixed-t...   5.78%
#
#   Current_Price Annual_Div  52_Wk_High  52_Wk_Low  Perp_Value Buy_Ind
# 0        $25.65      $2.06       25.98      24.81       25.62       0
# 1        $25.47      $1.94       25.95      24.59       25.49       1
# 2        $25.82      $1.72       28.80      25.52       25.83       1
# 3        $25.95      $1.94       26.87      25.28       25.97       1
# 4        $25.72      $1.49       28.99      25.21       25.78       1

# %%
data.describe()
# Out:
#        52_Wk_High  52_Wk_Low  Perp_Value
# count   20.000000  20.000000    20.00000
# mean    20.360000  18.674000    25.39050
# std     12.104817  11.074259     0.85936
# min      0.000000   0.000000    23.74000
# 25%     19.027500  17.782500    25.00000
# 50%     25.990000  24.710000    25.61500
# 75%     27.800000  25.280000    25.92500
# max     28.990000  25.600000    26.63000
